# %% [markdown]
# # Bước 1 : Khai báo thư viện

# %%
import numpy as np #đọc dữ liệu
import pandas as pd #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu

from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import SimpleRNN #học phụ thuộc
from keras.layers import Dense #đầu ra

# %% [markdown]
# # Bước 2 : Đọc dữ liệu

# %%
df = pd.read_csv(r"C:\Users\ADMIN\OneDrive\Máy tính\IS403\IS403_O22_HTCL_11\Dataset\AMD.csv")
df.shape
# Out:
# (1323, 7)

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2019-03-01  23.969999  24.190001  23.450001  23.680000  23.680000  48084000
# 1  2019-03-04  23.889999  24.129999  23.010000  23.370001  23.370001  48147700
# 2  2019-03-05  23.340000  23.680000  23.010000  23.500000  23.500000  35462600
# 3  2019-03-06  23.469999  23.530001  22.400000  22.410000  22.410000  60479400
# 4  2019-03-07  22.330000  22.410000  21.730000  22.080000  22.080000  52186300

# %% [markdown]
# # Bước 3 : Tiền xử lí dữ liệu

# %%
#lấy dữ liệu và gắn index với giá Close 
df1=df.reset_index()['Close']
df1
# Out:
# 0        23.680000
# 1        23.370001
# 2        23.500000
# 3        22.410000
# 4        22.080000
#            ...
# 1318    166.360001
# 1319    171.610001
# 1320    165.139999
# 1321    166.750000
# 1322    166.899994
# Name: Close, Length: 1323, dtype: float64

# %%
#lập biểu đồ giá đóng cửa 
plt.figure (figsize=(10, 5))
plt.plot(df1, label='giá thực tế', color='blue') #lập biểu đồ
plt.title('biểu đồ giá đóng cửa') #đặt tên biểu đồ
plt.xlabel('thời gian') #đặt tên hàm x 
plt.ylabel('giá đóng cửa') #đặt tên hàm y 
plt.legend() #chú thích 
plt.show()

# %%
#chia dữ liệu thành train và test (70% train, 30% test)
data=df1.values.reshape(-1, 1)
train_size = int(len(data) * 0.7)
train_data = data[:train_size]
test_data = data[train_size:]

# %%
# Chuẩn hóa dữ liệu 
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(train_data)
sc_test = sc.fit_transform(test_data)

# %% [markdown]
# Làm việc với tập train

# %%
#tạo vòng lặp các giá trị
time_step = 100

x_train,y_train=[],[]
for i in range(time_step,len(train_data)):
  x_train.append(sc_train[i-time_step:i,0]) #lấy 100 giá đóng cửa liên tục
  y_train.append(sc_train[i,0]) #lấy ra giá đóng cửa ngày hôm sau

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
y_train = np.reshape(y_train,(y_train.shape[0],1))

# %% [markdown]
# # Bước 4 : Xây dựng và huấn luyện mô hình

# %%
model = Sequential()
model.add(SimpleRNN(50, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Huấn luyện mô hình
save_model = "save_model_7_3.keras"
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=50, batch_size=16, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/50
#
# Epoch 1: loss improved from inf to 0.02085, saving model to save_model_7_3.keras
# 52/52 - 1s - 28ms/step - loss: 0.0209
# Epoch 2/50
#
# Epoch 2: loss improved from 0.02085 to 0.00168, saving model to save_model_7_3.keras
# 52/52 - 0s - 7ms/step - loss: 0.0017
# Epoch 3/50
#
# Epoch 3: loss improved from 0.00168 to 0.00134, saving model to save_model_7_3.keras
# 52/52 - 0s - 7ms/step - loss: 0.0013
# Epoch 4/50
#
# Epoch 4: loss improved from 0.00134 to 0.00116, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 0.0012
# Epoch 5/50
#
# Epoch 5: loss improved from 0.00116 to 0.00102, saving model to save_model_7_3.keras
# 52/52 - 0s - 6ms/step - loss: 0.0010
# Epoch 6/50
#
# Epoch 6: loss improved from 0.00102 to 0.00097, saving model to save_model_7_3.keras
# 52/52 - 0s - 7ms/step - loss: 9.6785e-04
# Epoch 7/50
#
# Epoch 7: loss improved from 0.00097 to 0.00090, saving model to save_model_7_3.keras
# 52/52 - 0s - 7ms/step - loss: 8.9611e-04
# Epoch 8/50
#
# Epoch 8: loss did not improve from 0.00090
# 52/52 - 0s - 7ms/step - loss: 9.4044e-04
# Epoch 9/50
#
# Epoch 9: loss improved from 0.00090 to 0.00083, saving model to save_model_7_3.keras
# 52/52 - 0s - 7ms/step - loss: 8.3140e-04
# Epoch 10/50
#
# Epoch 10: loss improved from 0.00083 to 0.00076, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 7.5969e-04
# Epoch 11/50
#
# Epoch 11: loss improved from 0.00076 to 0.00072, saving model to save_model_7_3.keras
# 52/52 - 0s - 7ms/step - loss: 7.1745e-04
# Epoch 12/50
#
# Epoch 12: loss did not improve from 0.00072
# 52/52 - 0s - 7ms/step - loss: 7.5881e-04
# Epoch 13/50
#
# Epoch 13: loss did not improve from 0.00072
# 52/52 - 0s - 7ms/step - loss: 7.5267e-04
# Epoch 14/50
#
# Epoch 14: loss improved from 0.00072 to 0.00071, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 7.1486e-04
# Epoch 15/50
#
# Epoch 15: loss improved from 0.00071 to 0.00067, saving model to save_model_7_3.keras
# 52/52 - 0s - 9ms/step - loss: 6.7375e-04
# Epoch 16/50
#
# Epoch 16: loss did not improve from 0.00067
# 52/52 - 0s - 9ms/step - loss: 7.5054e-04
# Epoch 17/50
#
# Epoch 17: loss improved from 0.00067 to 0.00067, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 6.6813e-04
# Epoch 18/50
#
# Epoch 18: loss improved from 0.00067 to 0.00062, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 6.1743e-04
# Epoch 19/50
#
# Epoch 19: loss improved from 0.00062 to 0.00058, saving model to save_model_7_3.keras
# 52/52 - 1s - 10ms/step - loss: 5.8436e-04
# Epoch 20/50
#
# Epoch 20: loss did not improve from 0.00058
# 52/52 - 0s - 8ms/step - loss: 6.0998e-04
# Epoch 21/50
#
# Epoch 21: loss improved from 0.00058 to 0.00057, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 5.6830e-04
# Epoch 22/50
#
# Epoch 22: loss did not improve from 0.00057
# 52/52 - 1s - 13ms/step - loss: 5.9955e-04
# Epoch 23/50
#
# Epoch 23: loss improved from 0.00057 to 0.00056, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 5.6152e-04
# Epoch 24/50
#
# Epoch 24: loss improved from 0.00056 to 0.00055, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 5.4665e-04
# Epoch 25/50
#
# Epoch 25: loss improved from 0.00055 to 0.00054, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 5.4165e-04
# Epoch 26/50
#
# Epoch 26: loss did not improve from 0.00054
# 52/52 - 0s - 8ms/step - loss: 6.0639e-04
# Epoch 27/50
#
# Epoch 27: loss did not improve from 0.00054
# 52/52 - 0s - 8ms/step - loss: 5.5012e-04
# Epoch 28/50
#
# Epoch 28: loss did not improve from 0.00054
# 52/52 - 0s - 8ms/step - loss: 5.4872e-04
# Epoch 29/50
#
# Epoch 29: loss did not improve from 0.00054
# 52/52 - 0s - 8ms/step - loss: 6.1445e-04
# Epoch 30/50
#
# Epoch 30: loss did not improve from 0.00054
# 52/52 - 0s - 8ms/step - loss: 5.6405e-04
# Epoch 31/50
#
# Epoch 31: loss improved from 0.00054 to 0.00052, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 5.1724e-04
# Epoch 32/50
#
# Epoch 32: loss did not improve from 0.00052
# 52/52 - 0s - 8ms/step - loss: 5.2839e-04
# Epoch 33/50
#
# Epoch 33: loss did not improve from 0.00052
# 52/52 - 0s - 8ms/step - loss: 6.0854e-04
# Epoch 34/50
#
# Epoch 34: loss did not improve from 0.00052
# 52/52 - 0s - 8ms/step - loss: 5.2284e-04
# Epoch 35/50
#
# Epoch 35: loss improved from 0.00052 to 0.00051, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 5.0902e-04
# Epoch 36/50
#
# Epoch 36: loss improved from 0.00051 to 0.00048, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 4.8361e-04
# Epoch 37/50
#
# Epoch 37: loss did not improve from 0.00048
# 52/52 - 0s - 7ms/step - loss: 6.1252e-04
# Epoch 38/50
#
# Epoch 38: loss did not improve from 0.00048
# 52/52 - 0s - 7ms/step - loss: 4.9434e-04
# Epoch 39/50
#
# Epoch 39: loss did not improve from 0.00048
# 52/52 - 0s - 8ms/step - loss: 4.8781e-04
# Epoch 40/50
#
# Epoch 40: loss did not improve from 0.00048
# 52/52 - 0s - 7ms/step - loss: 4.9420e-04
# Epoch 41/50
#
# Epoch 41: loss did not improve from 0.00048
# 52/52 - 0s - 8ms/step - loss: 5.3794e-04
# Epoch 42/50
#
# Epoch 42: loss did not improve from 0.00048
# 52/52 - 0s - 8ms/step - loss: 5.1102e-04
# Epoch 43/50
#
# Epoch 43: loss improved from 0.00048 to 0.00048, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 4.7503e-04
# Epoch 44/50
#
# Epoch 44: loss did not improve from 0.00048
# 52/52 - 0s - 8ms/step - loss: 4.8001e-04
# Epoch 45/50
#
# Epoch 45: loss improved from 0.00048 to 0.00047, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 4.6639e-04
# Epoch 46/50
#
# Epoch 46: loss did not improve from 0.00047
# 52/52 - 0s - 8ms/step - loss: 5.5278e-04
# Epoch 47/50
#
# Epoch 47: loss did not improve from 0.00047
# 52/52 - 0s - 7ms/step - loss: 4.8651e-04
# Epoch 48/50
#
# Epoch 48: loss improved from 0.00047 to 0.00046, saving model to save_model_7_3.keras
# 52/52 - 0s - 8ms/step - loss: 4.5508e-04
# Epoch 49/50
#
# Epoch 49: loss did not improve from 0.00046
# 52/52 - 0s - 8ms/step - loss: 5.0098e-04
# Epoch 50/50
#
# Epoch 50: loss did not improve from 0.00046
# 52/52 - 0s - 8ms/step - loss: 4.9231e-04

# %%
#dữ liệu train
y_train = sc.inverse_transform(y_train) #giá thực
final_model = load_model("save_model_7_3.keras")
y_train_predict = final_model.predict(x_train) #dự đoán giá đóng cửa trên tập đã train
y_train_predict = sc.inverse_transform(y_train_predict) #chuyển về sô liệu thực
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# # Bước 5 : Sử dụng mô hình

# %%
# Chuẩn bị dữ liệu để đưa vào model 
x_test = []
for i in range(time_step ,test_data.shape[0]):
  x_test.append(sc_test[i-time_step:i,0])
  
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

y_test_predict = final_model.predict(x_test) # dự đoán giá đóng cửa trên tập đã test
y_test_predict = sc.inverse_transform(y_test_predict) #chuyển về số liệu thực
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# # Bước 6 : Dự báo tương lai và đánh giá

# %%
# Dự báo 30 ngày tới
temp_input = list(sc_test[-time_step:].flatten())  # Lấy 100 giá trị cuối cùng từ dữ liệu test đã chuẩn hóa
n_steps = time_step
i = 0
lst_output_30_days = []

while i < 30:
    if len(temp_input) > n_steps:
        x_input = np.array(temp_input[-n_steps:]).reshape((1, n_steps, 1))
        yhat = final_model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output_30_days.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps, 1))
        yhat = final_model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output_30_days.extend(yhat.tolist())
        i += 1

# Chuyển đổi giá trị dự báo về giá trị gốc
lst_output_30_days = sc.inverse_transform(lst_output_30_days)

# %%
# Dự báo 60 ngày tới
temp_input = list(sc_test[-time_step:].flatten())  # Lấy 100 giá trị cuối cùng từ dữ liệu test đã chuẩn hóa
n_steps = time_step
i = 0
lst_output_60_days = []

while i < 60:
    if len(temp_input) > n_steps:
        x_input = np.array(temp_input[-n_steps:]).reshape((1, n_steps, 1))
        yhat = final_model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output_60_days.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps, 1))
        yhat = final_model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output_60_days.extend(yhat.tolist())
        i += 1

# Chuyển đổi giá trị dự báo về giá trị gốc
lst_output_60_days = sc.inverse_transform(lst_output_60_days)

# %%
# Dự báo 90 ngày tới
temp_input = list(sc_test[-time_step:].flatten())  # Lấy 100 giá trị cuối cùng từ dữ liệu test đã chuẩn hóa
n_steps = time_step
i = 0
lst_output_90_days = []

while i < 90:
    if len(temp_input) > n_steps:
        x_input = np.array(temp_input[-n_steps:]).reshape((1, n_steps, 1))
        yhat = final_model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output_90_days.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps, 1))
        yhat = final_model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output_90_days.extend(yhat.tolist())
        i += 1

# Chuyển đổi giá trị dự báo về giá trị gốc
lst_output_90_days = sc.inverse_transform(lst_output_90_days)
print(lst_output_90_days)
# Out:
# [[167.68760203]
#  [166.94751562]
#  [165.51250166]
#  [164.50890053]
#  [163.20595804]
#  [162.10937153]
#  [161.84648503]
#  [161.75262561]
#  [160.56188833]
#  [159.81124057]
#  [159.02152493]
#  [157.74980215]
#  [156.67835347]
#  [155.23874168]
#  [154.81732572]
#  [153.62692531]
#  [152.89107254]
#  [151.96643569]
#  [150.95394846]
#  [151.53895606]
#  [150.20679688]
#  [149.02167714]
#  [148.39732853]
#  [147.68526611]
#  [147.0285415 ]
#  [146.66478503]
#  [146.6773676 ]
#  [146.1703592 ]
#  [144.26103149]
#  [143.21569483]
#  [142.17406375]
#  [141.11063622]
#  [141.00281033]
#  [140.74151714]
#  [140.20118586]
#  [139.75641657]
#  [138.66660389]
#  [137.61035081]
#  [137.28643611]
#  [136.58681058]
#  [136.17547342]
#  [135.49779   ]
#  [135.06451073]
#  [134.78578221]
#  [133.95744481]
#  [133.30654261]
#  [132.9481442 ]
#  [131.69383853]
#  [131.26594464]
#  [130.79562781]
#  [130.42375458]
#  [130.24723441]
#  [129.64663062]
#  [129.13360862]
#  [128.3780899 ]
#  [127.7287901 ]
#  [127.46741952]
#  [127.07001241]
#  [127.02026482]
#  [126.67797247]
#  [126.12217701]
#  [125.74368473]
#  [125.09613302]
#  [124.61282847]
#  [124.38135742]
#  [123.97075773]
#  [123.73675561]
#  [123.23918869]
#  [122.89591758]
#  [122.60287662]
#  [122.33459108]
#  [122.01582049]
#  [121.72725443]
#  [121.30218752]
#  [120.83320452]
#  [120.54034564]
#  [120.25705571]
#  [120.07465851]
#  [119.73349968]
#  [119.35844439]
#  [119.03954633]
#  [118.53266539]
#  [118.36392966]
#  [117.93589919]
#  [117.64615409]
#  [117.46854592]
#  [117.12096834]
#  [116.85315169]
#  [116.54656761]
#  [116.17255025]]

# %%
y_test_predict.shape
# Out:
# (297, 1)

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(train_data_index, train_data)

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+len(test_data), step=1)
plt.plot(test_data_index,test_data)

test_data_index = pd.RangeIndex(start=train_size+time_step, stop=train_size+len(test_data), step=1)
plt.plot(test_data_index, y_test_predict)

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+89, step=1)
plt.plot(prediect_data_index, lst_output_90_days)

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+59, step=1)
plt.plot(prediect_data_index, lst_output_60_days)

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(prediect_data_index, lst_output_30_days)

plt.legend(['Train','Test','Predict', 'Predict90days', 'Predict60days', 'Predict30days'])
plt.show()

# %%
# Hệ số đánh giá RMSE, MAE, MAPE
def evaluate_forecast(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))
    mae = np.mean(np.abs(y_true - y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    return rmse, mae, mape

y_true = test_data[100:]
y_pred = y_test_predict

rmse_score, mae_score, mape_score = evaluate_forecast(y_true, y_pred)

print("RMSE:", rmse_score)
print("MAE:", mae_score)
print("MAPE:", mape_score, "%")
# Out:
# RMSE: 4.188183030173939
# MAE: 3.048582949067498
# MAPE: 2.3035124520458314 %
